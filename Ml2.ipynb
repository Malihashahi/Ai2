# %%
import numpy as np
import pandas as pd
import seaborn  as sns 
from sklearn  import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('co2.csv')

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1', data = df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(9 ,9))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
x = df.drop("out1", axis =1)
x = x.drop("engine" , axis =1)
x = x.drop("cylandr" , axis =1)
y = df.out1

x
# Out:
#      fuelcomb
# 0         8.5
# 1         9.6
# 2         5.9
# 3        11.1
# 4        10.6
# ..        ...
# 495       6.9
# 496       7.5
# 497       7.7
# 498      10.6
# 499      10.8
#
# [500 rows x 1 columns]

# %%
X_train ,X_test ,y_train , y_test =train_test_split(x ,y ,test_size = 0.2)

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
out_robot =model.predict(X_test)

# %%
out_robot
# Out:
# array([212.74205038, 274.60002638, 297.23099321, 259.51271516,
#        304.77464882, 236.88174833, 359.0889692 , 328.91434677,
#        208.21585702, 230.84682384, 291.19606872, 291.19606872,
#        248.95159731, 330.42307789, 235.37301721, 185.58489019,
#        248.95159731, 258.00398404, 190.11108356, 236.88174833,
#        220.28570599, 378.70247379, 330.42307789, 321.37069116,
#        331.93180901, 211.23331926, 353.05404471, 470.73507222,
#        325.89688452, 294.21353096, 334.94927125, 250.46032843,
#        203.68966365, 350.03658247, 407.3683651 , 264.03890853,
#        303.26591769, 184.07615907, 197.65473916, 396.80724725,
#        232.35555497, 304.77464882, 359.0889692 , 200.67220141,
#        273.09129526, 223.30316824, 336.45800237, 250.46032843,
#        194.63727692, 239.89921058, 208.21585702, 235.37301721,
#        306.28337994, 259.51271516, 214.2507815 , 359.0889692 ,
#        194.63727692, 318.35322891, 199.16347029, 274.60002638,
#        202.18093253, 182.56742795, 353.05404471, 359.0889692 ,
#        218.77697487, 229.33809272, 384.73739827, 401.33344061,
#        350.03658247, 422.45567632, 248.95159731, 196.14600804,
#        331.93180901, 248.95159731, 241.4079417 , 342.49292686,
#        383.22866715, 200.67220141, 342.49292686, 279.12621974,
#        191.61981468, 348.52785135, 325.89688452, 229.33809272,
#        245.93413506, 267.05637077, 250.46032843, 202.18093253,
#        350.03658247, 261.02144628, 289.6873376 , 271.58256413,
#        274.60002638, 304.77464882, 259.51271516, 233.86428609,
#        233.86428609, 330.42307789, 274.60002638, 265.54763965])

# %%
y_test
# Out:
# 136    200
# 63     300
# 425    229
# 326    271
# 178    340
#       ...
# 160    232
# 105    232
# 73     380
# 184    294
# 107    281
# Name: out1, Length: 100, dtype: int64

# %%
X_test
# Out:
#      fuelcomb
# 136       8.7
# 63       12.8
# 425      14.3
# 326      11.8
# 178      14.8
# ..        ...
# 160      10.1
# 105      10.1
# 73       16.5
# 184      12.8
# 107      12.2
#
# [100 rows x 1 columns]

# %%
plt.scatter(X_test,y_test, color ='red')
plt.show()

# %%
plt.scatter(X_test,y_test, color ='red')
plt.plot(X_test ,out_robot, color ='black' , linewidth=2)
plt.show()

# %%
p206 = np.array([[3]])

# %%
p206
# Out:
# array([[3]])

# %%
co2 = model.predict(p206)
# Out:
# C:\Users\p\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
co2
# Out:
# array([126.74437644])
